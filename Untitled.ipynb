# %%
import os
import numpy as np 
import os
import nibabel as nib
import pandas as pd 
import matplotlib.pyplot as plt
from PIL import Image
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

import glob

from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *

from tqdm.notebook import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
file_list = []
for dirname, _, filenames in os.walk('segmentations'):
    for filename in filenames:
      file_list.append((dirname, filename))
        
for dirname, _, filenames in os.walk('volumes'):
    for filename in filenames:
      file_list.append((dirname, filename))

df_files = pd.DataFrame(file_list, columns=['dirname', 'filename'])
df_files.sort_values(by=['filename'], ascending=True)
print(df_files.head())
print(df_files.tail())
# Out:
#          dirname              filename
# 0  segmentations    segmentation-0.nii
# 1  segmentations    segmentation-1.nii
# 2  segmentations   segmentation-10.nii
# 3  segmentations  segmentation-100.nii
# 4  segmentations  segmentation-101.nii
#      dirname       filename
# 257  volumes  volume-95.nii
# 258  volumes  volume-96.nii
# 259  volumes  volume-97.nii
# 260  volumes  volume-98.nii
# 261  volumes  volume-99.nii

# %%
df_files["mask_dirname"] = "" ; df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"
    
    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = 'segmentations'

df_files_test= df_files[df_files.mask_filename=='']
# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True) 
print(len(df_files))
df_files
# Out:
# 131
#      dirname        filename   mask_dirname         mask_filename
# 0    volumes    volume-0.nii  segmentations    segmentation-0.nii
# 1    volumes    volume-1.nii  segmentations    segmentation-1.nii
# 2    volumes   volume-10.nii  segmentations   segmentation-10.nii
# 3    volumes  volume-100.nii  segmentations  segmentation-100.nii
# 4    volumes  volume-101.nii  segmentations  segmentation-101.nii
# ..       ...             ...            ...                   ...
# 126  volumes   volume-95.nii  segmentations   segmentation-95.nii
# 127  volumes   volume-96.nii  segmentations   segmentation-96.nii
# 128  volumes   volume-97.nii  segmentations   segmentation-97.nii
# 129  volumes   volume-98.nii  segmentations   segmentation-98.nii
# 130  volumes   volume-99.nii  segmentations   segmentation-99.nii
#
# [131 rows x 4 columns]

# %%
def read_nii(filepath):
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
sample = 0
sample_ct   = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask  = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])
print(sample_ct.shape) 
print(sample_mask.shape)
# Out:
# (512, 512, 75)
# (512, 512, 75)

# %%
dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

plt.imshow(tensor(sample_ct[...,50].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):

    fig = plt.figure(figsize=(18,15))

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')
    
    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')
    
    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')
    
    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')


    plt.show()

# %%
sample=56
sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[...,sample], sample_mask[...,sample]])

# %%
class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

    
#  Функция freqhist_bins разбивает диапазон значений пикселей на группы с примерно одинаковым количеством пикселей
@patch
def freqhist_bins(self:Tensor, n_bins=100):
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()
    
    
#  Функция hist_scaled масштабирует тензор на значения между 0 и 1, используя результат работы freqhist_bins
@patch
def hist_scaled(self:Tensor, brks=None):
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)
    
    
#  Функция to_nchan преобразует тензор в несколько каналов
@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))


#  Функция save_jpg сохраняет изображение в формате JPG, применяя необходимые преобразования (функции freqhist_bins, hist_scaled, to_nchan)
@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=90):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs=subplots(1,1)


#  Вывод тестового изображения
sample_slice.save_jpg('test.jpg', [dicom_windows.liver, dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0])
# Out:
# <Axes: >

# %%
def preprocess_nii(file_path):
    img = nib.load(file_path)
    data = img.get_fdata()
    return np.array(data)

# %%
liver_mask_list = []
tumor_mask_list = []
img_list = []

img_size = (256, 256)

count = 0
skip_next = False

for dir_name, file_name, mask_dir, mask_file in zip(df_files['dirname'], df_files['filename'], df_files['mask_dirname'], df_files['mask_filename']):
    if skip_next:
        skip_next = False
        continue

    index_list = []

    mask_data = preprocess_nii(f"{mask_dir}/{mask_file}")

    for i in range(mask_data.shape[2]):
        slice_data = np.array(mask_data[..., i]) > 0.5
        count += 1

        if slice_data.sum() > 0:
            resized_mask = np.array(Image.fromarray(mask_data[..., i]).resize(img_size))
            liver_mask_list.append(1.0 > (resized_mask < 1.1).astype(bool))
            tumor_mask_list.append((resized_mask.astype(bool)) ^ liver_mask_list[-1])
            index_list.append(i)

        elif count > 10:
            count = 0
            resized_mask = np.array(Image.fromarray(mask_data[..., i]).resize(img_size))
            liver_mask_list.append(1.0 > (resized_mask < 1.1).astype(bool))
            tumor_mask_list.append((resized_mask.astype(bool)) ^ liver_mask_list[-1])
            index_list.append(i)

    img_data = preprocess_nii(f"{dir_name}/{file_name}")

    for ind in index_list:
        img_slice = np.array(Image.fromarray(img_data[..., ind]).resize(img_size))
        img_list.append(img_slice)

    skip_next = True

# %%
print("img_list: ", len(img_list), " liver_mask_list: ", len(liver_mask_list), " tumor_mask_list: ", len(tumor_mask_list))
# Out:
# img_list:  11346  liver_mask_list:  11346  tumor_mask_list:  11346

# %%
x_train, x_temp, y_train, y_temp = train_test_split(img, np.stack([liver_mask_list, tumor_mask_list, np.logical_and(~np.array(liver_mask_list), ~np.array(tumor_mask_list))], axis=-1), test_size=0.25, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_temp, y_temp, test_size=1/5, random_state=42)

# %%
x_train, y_train, x_valid, y_valid, x_test, y_test = map(np.array, [x_train, y_train, x_valid, y_valid, x_test, y_test])

# %%
y_train.shape, x_train.shape
# Out:
# ((8509, 256, 256, 3), (8509, 256, 256))

# %%
def create_fcn_model(input_shape=(256, 256, 1), target_shape=(256, 256, 3)):
    model = keras.Sequential()

    # Кодировщик
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Декодировщик
    model.add(layers.UpSampling2D((2, 2)))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.UpSampling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.UpSampling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.UpSampling2D((2, 2)))
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(3, (1, 1), activation='softmax'))  

    crop_height = (model.output_shape[1] - target_shape[0]) // 2
    crop_width = (model.output_shape[2] - target_shape[1]) // 2
    model.add(layers.Cropping2D(cropping=((crop_height, crop_height), (crop_width, crop_width))))

    return model

# %%
from tensorflow.keras import backend as K

class JaccardIndex(tf.keras.metrics.Metric):
    def __init__(self, class_id, name='jaccard_index', **kwargs):
        self.class_id=class_id
        super(JaccardIndex, self).__init__(name=name, **kwargs)
        self.jac = self.add_weight(name='jac', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true[:,:,:,self.class_id], tf.float32)
        y_pred = tf.cast(y_pred[:,:,:,self.class_id], tf.float32)
        intersection = tf.reduce_sum(y_true * y_pred, axis=(1,2))
        sum_ = tf.reduce_sum(y_true + y_pred, axis=(1,2))
        jac = (intersection + 100) / (sum_ - intersection + 100)
        self.jac.assign_add(tf.reduce_mean(jac))
        self.count.assign_add(1)

    def result(self):
        return self.jac / tf.cast(self.count, tf.float32)

    def reset_states(self):
        self.jac.assign(0.)
        self.count.assign(0.)

def jaccard_index(y_true, y_pred, smooth=100):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=(1,2))
    sum_ = tf.reduce_sum(y_true + y_pred, axis=(1,2))
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return tf.reduce_mean(jac)

def dice_coefficient(y_true, y_pred):
    smooth = 1.0
    
    y_true = K.cast(y_true, dtype='float32')
    
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)
    
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return dice

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint("model_final.keras", monitor='val_loss', verbose=1,save_best_only=True, mode='auto')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-10)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall

model_final = create_fcn_model()
model_final.save('model_final.keras')
model_final.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=[JaccardIndex(0, name="tumor_jaccard"), JaccardIndex(1, name="liver_jaccard"), Recall(class_id=0, name="tumor_recall"), dice_coefficient])
# Out:
# C:\Users\User\PycharmProjects\liver_segmentation\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_final = model_final.fit(x_train, y_train, batch_size=16, epochs=30,
                                validation_data=(x_valid, y_valid), callbacks=[reduce_lr,checkpoint])
model_final.save('model_final.keras')
# Out:
# Epoch 1/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8871 - liver_jaccard: 0.3772 - loss: 0.2070 - tumor_jaccard: 0.2263 - tumor_recall: 0.0034
# Epoch 1: val_loss improved from inf to 0.06575, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2330s 4s/step - dice_coefficient: 0.8872 - liver_jaccard: 0.3774 - loss: 0.2068 - tumor_jaccard: 0.2265 - tumor_recall: 0.0034 - val_dice_coefficient: 0.9658 - val_liver_jaccard: 0.5720 - val_loss: 0.0657 - val_tumor_jaccard: 0.3266 - val_tumor_recall: 0.0000e+00 - learning_rate: 0.0100
# Epoch 2/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9696 - liver_jaccard: 0.5571 - loss: 0.0568 - tumor_jaccard: 0.4404 - tumor_recall: 0.0130
# Epoch 2: val_loss improved from 0.06575 to 0.04591, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2320s 4s/step - dice_coefficient: 0.9697 - liver_jaccard: 0.5572 - loss: 0.0568 - tumor_jaccard: 0.4405 - tumor_recall: 0.0131 - val_dice_coefficient: 0.9780 - val_liver_jaccard: 0.6564 - val_loss: 0.0459 - val_tumor_jaccard: 0.6601 - val_tumor_recall: 0.0000e+00 - learning_rate: 0.0100
# Epoch 3/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9769 - liver_jaccard: 0.6438 - loss: 0.0434 - tumor_jaccard: 0.5475 - tumor_recall: 0.2540
# Epoch 3: val_loss improved from 0.04591 to 0.03608, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2267s 4s/step - dice_coefficient: 0.9769 - liver_jaccard: 0.6438 - loss: 0.0434 - tumor_jaccard: 0.5475 - tumor_recall: 0.2541 - val_dice_coefficient: 0.9775 - val_liver_jaccard: 0.6640 - val_loss: 0.0361 - val_tumor_jaccard: 0.5257 - val_tumor_recall: 0.5097 - learning_rate: 0.0100
# Epoch 4/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9822 - liver_jaccard: 0.7004 - loss: 0.0325 - tumor_jaccard: 0.6282 - tumor_recall: 0.4515
# Epoch 4: val_loss improved from 0.03608 to 0.02982, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2281s 4s/step - dice_coefficient: 0.9822 - liver_jaccard: 0.7004 - loss: 0.0325 - tumor_jaccard: 0.6283 - tumor_recall: 0.4515 - val_dice_coefficient: 0.9845 - val_liver_jaccard: 0.7425 - val_loss: 0.0298 - val_tumor_jaccard: 0.6620 - val_tumor_recall: 0.4994 - learning_rate: 0.0100
# Epoch 5/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9857 - liver_jaccard: 0.7524 - loss: 0.0261 - tumor_jaccard: 0.6932 - tumor_recall: 0.5986
# Epoch 5: val_loss did not improve from 0.02982
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2378s 4s/step - dice_coefficient: 0.9857 - liver_jaccard: 0.7525 - loss: 0.0261 - tumor_jaccard: 0.6932 - tumor_recall: 0.5986 - val_dice_coefficient: 0.9853 - val_liver_jaccard: 0.7600 - val_loss: 0.0305 - val_tumor_jaccard: 0.7263 - val_tumor_recall: 0.5253 - learning_rate: 0.0100
# Epoch 6/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9889 - liver_jaccard: 0.8030 - loss: 0.0197 - tumor_jaccard: 0.7472 - tumor_recall: 0.6843
# Epoch 6: val_loss improved from 0.02982 to 0.02266, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2217s 4s/step - dice_coefficient: 0.9889 - liver_jaccard: 0.8030 - loss: 0.0197 - tumor_jaccard: 0.7472 - tumor_recall: 0.6843 - val_dice_coefficient: 0.9879 - val_liver_jaccard: 0.8047 - val_loss: 0.0227 - val_tumor_jaccard: 0.7253 - val_tumor_recall: 0.7680 - learning_rate: 0.0100
# Epoch 7/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9905 - liver_jaccard: 0.8290 - loss: 0.0169 - tumor_jaccard: 0.7768 - tumor_recall: 0.7268
# Epoch 7: val_loss improved from 0.02266 to 0.01674, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2348s 4s/step - dice_coefficient: 0.9905 - liver_jaccard: 0.8290 - loss: 0.0169 - tumor_jaccard: 0.7768 - tumor_recall: 0.7269 - val_dice_coefficient: 0.9907 - val_liver_jaccard: 0.8375 - val_loss: 0.0167 - val_tumor_jaccard: 0.7962 - val_tumor_recall: 0.6771 - learning_rate: 0.0100
# Epoch 8/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9921 - liver_jaccard: 0.8560 - loss: 0.0137 - tumor_jaccard: 0.8137 - tumor_recall: 0.7731
# Epoch 8: val_loss did not improve from 0.01674
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2385s 4s/step - dice_coefficient: 0.9921 - liver_jaccard: 0.8560 - loss: 0.0137 - tumor_jaccard: 0.8137 - tumor_recall: 0.7731 - val_dice_coefficient: 0.9893 - val_liver_jaccard: 0.8004 - val_loss: 0.0191 - val_tumor_jaccard: 0.7705 - val_tumor_recall: 0.7694 - learning_rate: 0.0100
# Epoch 9/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9929 - liver_jaccard: 0.8698 - loss: 0.0124 - tumor_jaccard: 0.8307 - tumor_recall: 0.8021
# Epoch 9: val_loss did not improve from 0.01674
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2216s 4s/step - dice_coefficient: 0.9929 - liver_jaccard: 0.8698 - loss: 0.0124 - tumor_jaccard: 0.8307 - tumor_recall: 0.8021 - val_dice_coefficient: 0.9904 - val_liver_jaccard: 0.8369 - val_loss: 0.0174 - val_tumor_jaccard: 0.7069 - val_tumor_recall: 0.8357 - learning_rate: 0.0100
# Epoch 10/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9934 - liver_jaccard: 0.8753 - loss: 0.0116 - tumor_jaccard: 0.8430 - tumor_recall: 0.8151
# Epoch 10: val_loss improved from 0.01674 to 0.01335, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2219s 4s/step - dice_coefficient: 0.9934 - liver_jaccard: 0.8753 - loss: 0.0116 - tumor_jaccard: 0.8430 - tumor_recall: 0.8151 - val_dice_coefficient: 0.9927 - val_liver_jaccard: 0.8716 - val_loss: 0.0133 - val_tumor_jaccard: 0.8605 - val_tumor_recall: 0.7808 - learning_rate: 0.0100
# Epoch 11/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9943 - liver_jaccard: 0.8992 - loss: 0.0099 - tumor_jaccard: 0.8631 - tumor_recall: 0.8346
# Epoch 11: val_loss improved from 0.01335 to 0.01113, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2217s 4s/step - dice_coefficient: 0.9943 - liver_jaccard: 0.8992 - loss: 0.0099 - tumor_jaccard: 0.8631 - tumor_recall: 0.8346 - val_dice_coefficient: 0.9941 - val_liver_jaccard: 0.9021 - val_loss: 0.0111 - val_tumor_jaccard: 0.8762 - val_tumor_recall: 0.8514 - learning_rate: 0.0100
# Epoch 12/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9934 - liver_jaccard: 0.8827 - loss: 0.0116 - tumor_jaccard: 0.8425 - tumor_recall: 0.8027
# Epoch 12: val_loss did not improve from 0.01113
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2218s 4s/step - dice_coefficient: 0.9934 - liver_jaccard: 0.8827 - loss: 0.0116 - tumor_jaccard: 0.8424 - tumor_recall: 0.8027 - val_dice_coefficient: 0.9934 - val_liver_jaccard: 0.8839 - val_loss: 0.0129 - val_tumor_jaccard: 0.8386 - val_tumor_recall: 0.8342 - learning_rate: 0.0100
# Epoch 13/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9946 - liver_jaccard: 0.9016 - loss: 0.0093 - tumor_jaccard: 0.8726 - tumor_recall: 0.8515
# Epoch 13: val_loss did not improve from 0.01113
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2212s 4s/step - dice_coefficient: 0.9946 - liver_jaccard: 0.9016 - loss: 0.0093 - tumor_jaccard: 0.8726 - tumor_recall: 0.8515 - val_dice_coefficient: 0.9934 - val_liver_jaccard: 0.8735 - val_loss: 0.0117 - val_tumor_jaccard: 0.8717 - val_tumor_recall: 0.8488 - learning_rate: 0.0100
# Epoch 14/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9946 - liver_jaccard: 0.9024 - loss: 0.0091 - tumor_jaccard: 0.8777 - tumor_recall: 0.8557
# Epoch 14: val_loss did not improve from 0.01113
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2223s 4s/step - dice_coefficient: 0.9946 - liver_jaccard: 0.9024 - loss: 0.0091 - tumor_jaccard: 0.8777 - tumor_recall: 0.8557 - val_dice_coefficient: 0.9935 - val_liver_jaccard: 0.8726 - val_loss: 0.0124 - val_tumor_jaccard: 0.8664 - val_tumor_recall: 0.7993 - learning_rate: 0.0100
# Epoch 15/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9958 - liver_jaccard: 0.9268 - loss: 0.0069 - tumor_jaccard: 0.9075 - tumor_recall: 0.8954
# Epoch 15: val_loss improved from 0.01113 to 0.00831, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2216s 4s/step - dice_coefficient: 0.9958 - liver_jaccard: 0.9268 - loss: 0.0069 - tumor_jaccard: 0.9076 - tumor_recall: 0.8954 - val_dice_coefficient: 0.9955 - val_liver_jaccard: 0.9238 - val_loss: 0.0083 - val_tumor_jaccard: 0.9052 - val_tumor_recall: 0.8964 - learning_rate: 0.0050
# Epoch 16/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9964 - liver_jaccard: 0.9377 - loss: 0.0060 - tumor_jaccard: 0.9200 - tumor_recall: 0.9072
# Epoch 16: val_loss did not improve from 0.00831
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2222s 4s/step - dice_coefficient: 0.9964 - liver_jaccard: 0.9377 - loss: 0.0060 - tumor_jaccard: 0.9199 - tumor_recall: 0.9072 - val_dice_coefficient: 0.9950 - val_liver_jaccard: 0.9068 - val_loss: 0.0092 - val_tumor_jaccard: 0.8831 - val_tumor_recall: 0.8824 - learning_rate: 0.0050
# Epoch 17/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9964 - liver_jaccard: 0.9365 - loss: 0.0060 - tumor_jaccard: 0.9163 - tumor_recall: 0.9034
# Epoch 17: val_loss improved from 0.00831 to 0.00818, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2214s 4s/step - dice_coefficient: 0.9964 - liver_jaccard: 0.9365 - loss: 0.0060 - tumor_jaccard: 0.9163 - tumor_recall: 0.9035 - val_dice_coefficient: 0.9958 - val_liver_jaccard: 0.9246 - val_loss: 0.0082 - val_tumor_jaccard: 0.9031 - val_tumor_recall: 0.9071 - learning_rate: 0.0050
# Epoch 18/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9966 - liver_jaccard: 0.9423 - loss: 0.0056 - tumor_jaccard: 0.9227 - tumor_recall: 0.9140
# Epoch 18: val_loss did not improve from 0.00818
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2220s 4s/step - dice_coefficient: 0.9966 - liver_jaccard: 0.9423 - loss: 0.0056 - tumor_jaccard: 0.9227 - tumor_recall: 0.9140 - val_dice_coefficient: 0.9957 - val_liver_jaccard: 0.9231 - val_loss: 0.0088 - val_tumor_jaccard: 0.9159 - val_tumor_recall: 0.8559 - learning_rate: 0.0050
# Epoch 19/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9965 - liver_jaccard: 0.9394 - loss: 0.0058 - tumor_jaccard: 0.9215 - tumor_recall: 0.9137
# Epoch 19: val_loss improved from 0.00818 to 0.00807, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2221s 4s/step - dice_coefficient: 0.9965 - liver_jaccard: 0.9394 - loss: 0.0058 - tumor_jaccard: 0.9215 - tumor_recall: 0.9137 - val_dice_coefficient: 0.9959 - val_liver_jaccard: 0.9283 - val_loss: 0.0081 - val_tumor_jaccard: 0.9089 - val_tumor_recall: 0.9072 - learning_rate: 0.0050
# Epoch 20/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9967 - liver_jaccard: 0.9441 - loss: 0.0054 - tumor_jaccard: 0.9284 - tumor_recall: 0.9195
# Epoch 20: val_loss did not improve from 0.00807
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2248s 4s/step - dice_coefficient: 0.9967 - liver_jaccard: 0.9441 - loss: 0.0054 - tumor_jaccard: 0.9284 - tumor_recall: 0.9195 - val_dice_coefficient: 0.9959 - val_liver_jaccard: 0.9298 - val_loss: 0.0085 - val_tumor_jaccard: 0.9104 - val_tumor_recall: 0.9145 - learning_rate: 0.0050
# Epoch 21/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9967 - liver_jaccard: 0.9440 - loss: 0.0055 - tumor_jaccard: 0.9260 - tumor_recall: 0.9196
# Epoch 21: val_loss did not improve from 0.00807
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2411s 5s/step - dice_coefficient: 0.9967 - liver_jaccard: 0.9440 - loss: 0.0055 - tumor_jaccard: 0.9260 - tumor_recall: 0.9196 - val_dice_coefficient: 0.9933 - val_liver_jaccard: 0.8959 - val_loss: 0.0148 - val_tumor_jaccard: 0.7381 - val_tumor_recall: 0.9643 - learning_rate: 0.0050
# Epoch 22/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9962 - liver_jaccard: 0.9296 - loss: 0.0064 - tumor_jaccard: 0.9123 - tumor_recall: 0.9042
# Epoch 22: val_loss improved from 0.00807 to 0.00750, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2251s 4s/step - dice_coefficient: 0.9962 - liver_jaccard: 0.9296 - loss: 0.0064 - tumor_jaccard: 0.9123 - tumor_recall: 0.9042 - val_dice_coefficient: 0.9963 - val_liver_jaccard: 0.9352 - val_loss: 0.0075 - val_tumor_jaccard: 0.9237 - val_tumor_recall: 0.8639 - learning_rate: 0.0050
# Epoch 23/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9971 - liver_jaccard: 0.9497 - loss: 0.0049 - tumor_jaccard: 0.9342 - tumor_recall: 0.9269
# Epoch 23: val_loss did not improve from 0.00750
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2364s 4s/step - dice_coefficient: 0.9971 - liver_jaccard: 0.9497 - loss: 0.0049 - tumor_jaccard: 0.9342 - tumor_recall: 0.9269 - val_dice_coefficient: 0.9963 - val_liver_jaccard: 0.9368 - val_loss: 0.0077 - val_tumor_jaccard: 0.9234 - val_tumor_recall: 0.9137 - learning_rate: 0.0050
# Epoch 24/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9512 - loss: 0.0047 - tumor_jaccard: 0.9382 - tumor_recall: 0.9328
# Epoch 24: val_loss did not improve from 0.00750
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2283s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9512 - loss: 0.0047 - tumor_jaccard: 0.9382 - tumor_recall: 0.9328 - val_dice_coefficient: 0.9962 - val_liver_jaccard: 0.9289 - val_loss: 0.0076 - val_tumor_jaccard: 0.9199 - val_tumor_recall: 0.9043 - learning_rate: 0.0050
# Epoch 25/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9521 - loss: 0.0046 - tumor_jaccard: 0.9359 - tumor_recall: 0.9290
# Epoch 25: val_loss improved from 0.00750 to 0.00739, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2297s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9521 - loss: 0.0046 - tumor_jaccard: 0.9359 - tumor_recall: 0.9290 - val_dice_coefficient: 0.9966 - val_liver_jaccard: 0.9382 - val_loss: 0.0074 - val_tumor_jaccard: 0.9254 - val_tumor_recall: 0.9201 - learning_rate: 0.0050
# Epoch 26/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9526 - loss: 0.0046 - tumor_jaccard: 0.9386 - tumor_recall: 0.9328
# Epoch 26: val_loss improved from 0.00739 to 0.00725, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2306s 4s/step - dice_coefficient: 0.9972 - liver_jaccard: 0.9526 - loss: 0.0046 - tumor_jaccard: 0.9386 - tumor_recall: 0.9328 - val_dice_coefficient: 0.9966 - val_liver_jaccard: 0.9385 - val_loss: 0.0072 - val_tumor_jaccard: 0.9271 - val_tumor_recall: 0.9241 - learning_rate: 0.0050
# Epoch 27/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9974 - liver_jaccard: 0.9542 - loss: 0.0044 - tumor_jaccard: 0.9397 - tumor_recall: 0.9312
# Epoch 27: val_loss did not improve from 0.00725
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2357s 4s/step - dice_coefficient: 0.9974 - liver_jaccard: 0.9542 - loss: 0.0044 - tumor_jaccard: 0.9397 - tumor_recall: 0.9312 - val_dice_coefficient: 0.9967 - val_liver_jaccard: 0.9412 - val_loss: 0.0073 - val_tumor_jaccard: 0.9296 - val_tumor_recall: 0.8701 - learning_rate: 0.0050
# Epoch 28/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9974 - liver_jaccard: 0.9562 - loss: 0.0043 - tumor_jaccard: 0.9408 - tumor_recall: 0.9341
# Epoch 28: val_loss improved from 0.00725 to 0.00712, saving model to model_final.keras
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2257s 4s/step - dice_coefficient: 0.9974 - liver_jaccard: 0.9562 - loss: 0.0043 - tumor_jaccard: 0.9409 - tumor_recall: 0.9341 - val_dice_coefficient: 0.9967 - val_liver_jaccard: 0.9409 - val_loss: 0.0071 - val_tumor_jaccard: 0.9308 - val_tumor_recall: 0.9203 - learning_rate: 0.0050
# Epoch 29/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9975 - liver_jaccard: 0.9563 - loss: 0.0042 - tumor_jaccard: 0.9457 - tumor_recall: 0.9399
# Epoch 29: val_loss did not improve from 0.00712
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2286s 4s/step - dice_coefficient: 0.9975 - liver_jaccard: 0.9563 - loss: 0.0042 - tumor_jaccard: 0.9457 - tumor_recall: 0.9399 - val_dice_coefficient: 0.9967 - val_liver_jaccard: 0.9387 - val_loss: 0.0072 - val_tumor_jaccard: 0.9296 - val_tumor_recall: 0.9215 - learning_rate: 0.0050
# Epoch 30/30
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.9975 - liver_jaccard: 0.9574 - loss: 0.0041 - tumor_jaccard: 0.9441 - tumor_recall: 0.9413
# Epoch 30: val_loss did not improve from 0.00712
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 2275s 4s/step - dice_coefficient: 0.9975 - liver_jaccard: 0.9574 - loss: 0.0041 - tumor_jaccard: 0.9441 - tumor_recall: 0.9413 - val_dice_coefficient: 0.9965 - val_liver_jaccard: 0.9350 - val_loss: 0.0076 - val_tumor_jaccard: 0.9249 - val_tumor_recall: 0.9182 - learning_rate: 0.0050

# %%
def show_history(history_final, train, validation):
    plt.plot(history_final.history[train])
    plt.plot(history_final.history[validation])
    plt.title('History')
    plt.ylabel(train) 
    plt.xlabel('Epochs')
    plt.legend(['train', 'validation'], loc='center right')
    plt.show()

# %%
show_history(history_final, 'dice_coefficient', 'val_dice_coefficient')

# %%
show_history(history_final, 'liver_jaccard', 'val_liver_jaccard')

# %%
show_history(history_final, 'tumor_jaccard', 'val_tumor_jaccard')

# %%
show_history(history_final, 'tumor_recall', 'val_tumor_recall')

# %%
show_history(history_final, 'loss', 'val_loss')

# %%
import numpy as np

mask_colors = np.array([[255, 255, 255],  
                   [128, 128, 128],])  

for i in range(20):
    image_index = random.randint(0, len(x_test) - 1)
    input_image = x_test[image_index]
    true_mask = y_test[image_index]

    predicted_mask = model_final.predict(np.expand_dims(input_image, axis=0))[0]
    predicted_mask_binary = (predicted_mask > 0.5)

    combined_mask = np.zeros((predicted_mask_binary.shape[0], predicted_mask_binary.shape[1], 3))
    combined_true = np.zeros((true_mask.shape[0], true_mask.shape[1], 3))

    for class_index in range(2):
        combined_mask[predicted_mask_binary[:, :, class_index]] = mask_colors[class_index]
        combined_true[true_mask[:, :, class_index]] = mask_colors[class_index]

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(input_image)
    plt.title('Original Image')

    plt.subplot(1, 3, 2)
    plt.imshow(combined_true.astype(int))
    plt.title('True Mask')

    plt.subplot(1, 3, 3)
    plt.imshow(combined_mask.astype(int))
    plt.title('Combined Predicted Mask')

    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
