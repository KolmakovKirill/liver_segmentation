# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import glob
import nibabel as nib

from tqdm.notebook import tqdm

from PIL import Image

from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *

from tqdm.notebook import tqdm
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split

# %%
file_list = []
for dirname, _, filenames in os.walk('dataset/segmentations'):
    for filename in filenames:
      file_list.append((dirname, filename))
        
for dirname, _, filenames in os.walk('dataset/volumes'):
    for filename in filenames:
      file_list.append((dirname, filename))

df_files = pd.DataFrame(file_list, columns=['dirname', 'filename'])
df_files.sort_values(by=['filename'], ascending=True)
print(df_files.head())
print(df_files.tail())
# Out:
#                  dirname              filename
# 0  dataset/segmentations    segmentation-0.nii
# 1  dataset/segmentations    segmentation-1.nii
# 2  dataset/segmentations   segmentation-10.nii
# 3  dataset/segmentations  segmentation-100.nii
# 4  dataset/segmentations  segmentation-101.nii
#              dirname       filename
# 257  dataset/volumes  volume-95.nii
# 258  dataset/volumes  volume-96.nii
# 259  dataset/volumes  volume-97.nii
# 260  dataset/volumes  volume-98.nii
# 261  dataset/volumes  volume-99.nii

# %%
df_files["mask_dirname"] = "" ; df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"
    
    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = 'dataset/segmentations'

df_files_test= df_files[df_files.mask_filename=='']
# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True) 
print(len(df_files))
df_files
# Out:
# 131
#              dirname        filename           mask_dirname  \
# 0    dataset/volumes    volume-0.nii  dataset/segmentations
# 1    dataset/volumes    volume-1.nii  dataset/segmentations
# 2    dataset/volumes   volume-10.nii  dataset/segmentations
# 3    dataset/volumes  volume-100.nii  dataset/segmentations
# 4    dataset/volumes  volume-101.nii  dataset/segmentations
# ..               ...             ...                    ...
# 126  dataset/volumes   volume-95.nii  dataset/segmentations
# 127  dataset/volumes   volume-96.nii  dataset/segmentations
# 128  dataset/volumes   volume-97.nii  dataset/segmentations
# 129  dataset/volumes   volume-98.nii  dataset/segmentations
# 130  dataset/volumes   volume-99.nii  dataset/segmentations
#
#             mask_filename
# 0      segmentation-0.nii
# 1      segmentation-1.nii
# 2     segmentation-10.nii
# 3    segmentation-100.nii
# 4    segmentation-101.nii
# ..                    ...
# 126   segmentation-95.nii
# 127   segmentation-96.nii
# 128   segmentation-97.nii
# 129   segmentation-98.nii
# 130   segmentation-99.nii
#
# [131 rows x 4 columns]

# %%
def read_nii(filepath):
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
sample = 0
sample_ct   = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask  = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])
print(sample_ct.shape) 
print(sample_mask.shape)
# Out:
# (512, 512, 75)
# (512, 512, 75)

# %%
dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

plt.imshow(tensor(sample_ct[...,50].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):

    fig = plt.figure(figsize=(18,15))

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')
    
    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')
    
    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')
    
    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')


    plt.show()

# %%
sample=56
sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[...,sample], sample_mask[...,sample]])

# %%
class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

    
#  Функция freqhist_bins разбивает диапазон значений пикселей на группы с примерно одинаковым количеством пикселей
@patch
def freqhist_bins(self:Tensor, n_bins=100):
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()
    
    
#  Функция hist_scaled масштабирует тензор на значения между 0 и 1, используя результат работы freqhist_bins
@patch
def hist_scaled(self:Tensor, brks=None):
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)
    
    
#  Функция to_nchan преобразует тензор в несколько каналов
@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))


#  Функция save_jpg сохраняет изображение в формате JPG, применяя необходимые преобразования (функции freqhist_bins, hist_scaled, to_nchan)
@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=90):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs=subplots(1,1)


#  Вывод тестового изображения
sample_slice.save_jpg('test.jpg', [dicom_windows.liver, dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0])
# Out:
# <Axes: >

# %%
import random

GENERATE_JPG_FILES = True   # warning: generation takes ~ 1h

if GENERATE_JPG_FILES:
    path = Path(".")

    os.makedirs('train_images', exist_ok=True)
    os.makedirs('train_masks', exist_ok=True)

    random_indices = random.sample(range(len(df_files)), len(df_files) )

    for ii in tqdm(random_indices):  
        curr_ct = read_nii(df_files.loc[ii, 'dirname'] + "/" + df_files.loc[ii, 'filename'])
        curr_mask = read_nii(df_files.loc[ii, 'mask_dirname'] + "/" + df_files.loc[ii, 'mask_filename'])
        curr_file_name = str(df_files.loc[ii, 'filename']).split('.')[0]
        curr_dim = curr_ct.shape[2]  

        for curr_slice in range(0, curr_dim, 2): 
            data = tensor(curr_ct[..., curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[..., curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver, dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")
# Out:
#   0%|          | 0/131 [00:00<?, ?it/s]

# %%
import os
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from PIL import Image
from sklearn.model_selection import train_test_split

# Set the directories
images_dir = 'train_images'
masks_dir = 'train_masks'

all_image_file_names = sorted(os.listdir(images_dir))

selected_image_file_names = random.sample(all_image_file_names, 5000)

target_size = (256, 256)
images = [np.array(Image.open(os.path.join(images_dir, fname)).resize(target_size)) for fname in selected_image_file_names]

mask_file_names = [fname.replace('.jpg', '_mask.png') for fname in selected_image_file_names]
masks = [np.array(Image.open(os.path.join(masks_dir, fname)).resize(target_size)) for fname in mask_file_names]

images = np.array(images)
masks = np.array(masks)

images = images / 255.0

masks = masks.reshape((masks.shape[0], masks.shape[1], masks.shape[2], 1))

# %%
images.shape
# Out:
# (5000, 256, 256, 3)

# %%
image_liver = []
mask_liver = []

for idx, img in enumerate(masks):

    unique_colors = np.unique(img)
    
    if len(unique_colors) == 1:
        image_liver.append(images[idx])
        mask_liver.append(masks[idx])
    
    if len(unique_colors) == 2:
        image_liver.append(images[idx])

        black_background = np.zeros_like(img)
        mask_liver.append(masks[idx])

    elif len(unique_colors) == 3:
        # Make grey pixels white in Y_train1
        image_liver.append(images[idx])
        
        # Keep only white pixels in Y_train2
        img_white_bg = np.where(img == 1, 2, img)
        mask_liver.append(img_white_bg)
        
image_liver = np.array(image_liver)
mask_liver = np.array(mask_liver)

print("image_liver shape:", image_liver.shape)
print("mask_liver shape:", mask_liver.shape)
# Out:
# image_liver shape: (5000, 256, 256, 3)
# mask_liver shape: (5000, 256, 256, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np

num_samples = min(3, len(image_liver))

indices = np.random.choice(len(image_liver), num_samples, replace=False)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 18))

for i, idx in enumerate(indices):
    axes[i, 0].imshow(image_liver[idx], cmap='gray')  
    axes[i, 0].set_title(f"Image {idx} - Liver")
    axes[i, 0].axis('off')
    
    axes[i, 1].imshow(mask_liver[idx], cmap='gray')  
    axes[i, 1].set_title(f"Mask {idx} - liver")
    axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
x_train, x_temp, y_train, y_temp = train_test_split(image_liver, mask_liver, test_size=0.3, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_temp, y_temp, test_size=1/3, random_state=42)

# %%
y_train.shape, x_train.shape
# Out:
# ((3500, 256, 256, 1), (3500, 256, 256, 3))

# %%
import matplotlib.pyplot as plt

def display_images_and_masks(images, masks, num_samples=2):

    sample_indices = random.sample(range(images.shape[0]), num_samples)

    for i in range(num_samples):
        index = sample_indices[i]

        plt.subplot(num_samples, 2, 2 * i + 1)
        plt.imshow(images[index])
        plt.title("Image {}".format(index))
        plt.axis("off")

        plt.subplot(num_samples, 2, 2 * i + 2)
        plt.imshow(masks[index].squeeze(), cmap='gray')
        plt.title("Mask {}".format(index))
        plt.axis("off")

    plt.show()

display_images_and_masks(x_train, y_train)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPooling2D, Concatenate, UpSampling2D, Dropout, Reshape
from tensorflow.keras.models import Model

def dense_block(x, filters, dropout_rate=0.2):
    x1 = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x1 = Conv2D(filters, (3, 3), padding='same', activation='relu')(x1)
    x = Concatenate()([x, x1])
    
    return x

def transition_down_block(x, filters, dropout_rate=0.2):
    x = Conv2D(filters, (1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    return x

def transition_up_block(x, filters, skip_connection, dropout_rate=0.2):
    x = UpSampling2D((2, 2))(x)
    x = Concatenate()([x, skip_connection])
    x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
    
    return x

def build_densenet(input_shape=(256, 256, 3), dropout_rate=0.1):
    inputs = Input(shape=input_shape)
   
    x = Conv2D(128, (7, 7), strides=(2, 2), padding='same', activation='relu')(inputs)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
  
    x = dense_block(x, 64)
    x1 = x
    x = transition_down_block(x, 128)
    
    x = dense_block(x, 128)
    x2 = x
    x = transition_down_block(x, 256)

    x = transition_up_block(x, 256, x2)
    x = transition_up_block(x, 128, x1)
    #x = UpSampling2D((2, 2))(x)
    #x = UpSampling2D((2, 2))(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)


    outputs = Conv2D(1, (1, 1), activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# Build DenseNet model
model = build_densenet(input_shape=(256, 256, 3), dropout_rate=0.2)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 256, 256, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 128, 128, 128)     │          18,944 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 64, 64, 128)       │               0 │ conv2d_12[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 64, 64, 64)        │          73,792 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 64, 64, 64)        │          36,928 │ conv2d_13[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_4 (Concatenate)   │ (None, 64, 64, 192)       │               0 │ max_pooling2d_3[0][0],     │
# │                               │                           │                 │ conv2d_14[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 64, 64, 128)       │          24,704 │ concatenate_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 32, 32, 128)       │               0 │ conv2d_15[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 32, 32, 64)        │          73,792 │ max_pooling2d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 32, 32, 128)       │          73,856 │ conv2d_16[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_5 (Concatenate)   │ (None, 32, 32, 256)       │               0 │ max_pooling2d_4[0][0],     │
# │                               │                           │                 │ conv2d_17[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 32, 32, 256)       │          65,792 │ concatenate_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 16, 16, 256)       │               0 │ conv2d_18[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_4               │ (None, 32, 32, 256)       │               0 │ max_pooling2d_5[0][0]      │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_6 (Concatenate)   │ (None, 32, 32, 512)       │               0 │ up_sampling2d_4[0][0],     │
# │                               │                           │                 │ concatenate_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_19 (Conv2D)            │ (None, 32, 32, 256)       │       1,179,904 │ concatenate_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_5               │ (None, 64, 64, 256)       │               0 │ conv2d_19[0][0]            │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_7 (Concatenate)   │ (None, 64, 64, 448)       │               0 │ up_sampling2d_5[0][0],     │
# │                               │                           │                 │ concatenate_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_20 (Conv2D)            │ (None, 64, 64, 128)       │         516,224 │ concatenate_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_6               │ (None, 128, 128, 128)     │               0 │ conv2d_20[0][0]            │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_21 (Conv2D)            │ (None, 128, 128, 64)      │          73,792 │ up_sampling2d_6[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 128, 128, 64)      │             256 │ conv2d_21[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_7               │ (None, 256, 256, 64)      │               0 │ batch_normalization_2[0][… │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_22 (Conv2D)            │ (None, 256, 256, 32)      │          18,464 │ up_sampling2d_7[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 256, 256, 32)      │             128 │ conv2d_22[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_23 (Conv2D)            │ (None, 256, 256, 1)       │              33 │ batch_normalization_3[0][… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,156,609 (8.23 MB)
#  Trainable params: 2,156,417 (8.23 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
import tensorflow.keras.backend as K

def combined_loss(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    
    bce = K.mean(K.binary_crossentropy(y_true, y_pred), axis=-1)
    
    smooth = 1.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    
    combined_loss = bce - K.log(dice)
    
    return combined_loss

def dice_coefficient(y_true, y_pred):
    smooth = 1.0
    
    y_true = K.cast(y_true, dtype='float32')
    
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)
    
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return dice

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

checkpoint = ModelCheckpoint("model10.keras", monitor='val_loss', verbose=1, save_best_only=True,
                             save_weights_only=False, mode='auto')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1)

optimizer = Adam(learning_rate=0.005)

model.compile(optimizer=optimizer, loss=combined_loss, metrics=['accuracy', dice_coefficient])

# %%
try:
    print("Training started...")
    history = model.fit(x_train, y_train, epochs=20, batch_size=32,
                        validation_data=(x_valid, y_valid), 
                        callbacks=[reduce_lr, checkpoint])
    print("Training completed successfully.")

    # Save the model
    model.save('model_final7.keras')
    print("Model saved successfully.")

except Exception as e:
    print(f"Error encountered during training: {e}")
# Out:
# Training started...
# Epoch 1/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8161 - dice_coefficient: 0.1620 - loss: 2.5192
# Epoch 1: val_loss improved from inf to 2.97058, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 491s 4s/step - accuracy: 0.8168 - dice_coefficient: 0.1625 - loss: 2.5151 - val_accuracy: 0.8387 - val_dice_coefficient: 0.3082 - val_loss: 2.9706 - learning_rate: 0.0010
# Epoch 2/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9560 - dice_coefficient: 0.4095 - loss: 1.1555
# Epoch 2: val_loss improved from 2.97058 to 0.19026, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.9561 - dice_coefficient: 0.4103 - loss: 1.1528 - val_accuracy: 0.9815 - val_dice_coefficient: 0.8451 - val_loss: 0.1903 - learning_rate: 0.0010
# Epoch 3/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9757 - dice_coefficient: 0.7581 - loss: 0.2666
# Epoch 3: val_loss improved from 0.19026 to 0.06514, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.9757 - dice_coefficient: 0.7582 - loss: 0.2667 - val_accuracy: 0.9772 - val_dice_coefficient: 0.9280 - val_loss: 0.0651 - learning_rate: 0.0010
# Epoch 4/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9783 - dice_coefficient: 0.8590 - loss: 0.1219
# Epoch 4: val_loss improved from 0.06514 to -0.03825, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9783 - dice_coefficient: 0.8591 - loss: 0.1217 - val_accuracy: 0.9815 - val_dice_coefficient: 0.9853 - val_loss: -0.0383 - learning_rate: 0.0010
# Epoch 5/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9818 - dice_coefficient: 0.8973 - loss: 0.0742
# Epoch 5: val_loss did not improve from -0.03825
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9818 - dice_coefficient: 0.8975 - loss: 0.0738 - val_accuracy: 0.9770 - val_dice_coefficient: 0.1028 - val_loss: 2.8233 - learning_rate: 0.0010
# Epoch 6/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9810 - dice_coefficient: 0.9237 - loss: 0.0311
# Epoch 6: val_loss did not improve from -0.03825
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9810 - dice_coefficient: 0.9238 - loss: 0.0309 - val_accuracy: 0.9808 - val_dice_coefficient: 0.5999 - val_loss: 0.6256 - learning_rate: 0.0010
# Epoch 7/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9818 - dice_coefficient: 0.9670 - loss: -0.0311
# Epoch 7: val_loss improved from -0.03825 to -0.10935, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9818 - dice_coefficient: 0.9672 - loss: -0.0314 - val_accuracy: 0.9839 - val_dice_coefficient: 1.0147 - val_loss: -0.1093 - learning_rate: 0.0010
# Epoch 8/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.9988 - loss: -0.0817
# Epoch 8: val_loss improved from -0.10935 to -0.14052, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.9988 - loss: -0.0816 - val_accuracy: 0.9838 - val_dice_coefficient: 1.0369 - val_loss: -0.1405 - learning_rate: 0.0010
# Epoch 9/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9836 - dice_coefficient: 1.0076 - loss: -0.0867
# Epoch 9: val_loss did not improve from -0.14052
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9836 - dice_coefficient: 1.0076 - loss: -0.0867 - val_accuracy: 0.9805 - val_dice_coefficient: 1.0019 - val_loss: -0.0936 - learning_rate: 0.0010
# Epoch 10/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9805 - dice_coefficient: 0.9869 - loss: -0.0645
# Epoch 10: val_loss did not improve from -0.14052
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9805 - dice_coefficient: 0.9869 - loss: -0.0645 - val_accuracy: 0.9764 - val_dice_coefficient: 0.0129 - val_loss: 4.9672 - learning_rate: 0.0010
# Epoch 11/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.9843 - loss: -0.0462
# Epoch 11: val_loss did not improve from -0.14052
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9830 - dice_coefficient: 0.9844 - loss: -0.0465 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9655 - val_loss: -0.0270 - learning_rate: 0.0010
# Epoch 12/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9840 - dice_coefficient: 1.0480 - loss: -0.1512
# Epoch 12: val_loss did not improve from -0.14052
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9840 - dice_coefficient: 1.0479 - loss: -0.1510 - val_accuracy: 0.9813 - val_dice_coefficient: 0.6496 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 13/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9843 - dice_coefficient: 1.0342 - loss: -0.1226
# Epoch 13: val_loss did not improve from -0.14052
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9843 - dice_coefficient: 1.0343 - loss: -0.1228 - val_accuracy: 0.9824 - val_dice_coefficient: 0.7276 - val_loss: 0.3716 - learning_rate: 0.0010
# Epoch 14/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9850 - dice_coefficient: 1.0581 - loss: -0.1603
# Epoch 14: val_loss improved from -0.14052 to -0.19173, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9850 - dice_coefficient: 1.0582 - loss: -0.1605 - val_accuracy: 0.9852 - val_dice_coefficient: 1.0744 - val_loss: -0.1917 - learning_rate: 2.0000e-04
# Epoch 15/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9854 - dice_coefficient: 1.0904 - loss: -0.2072
# Epoch 15: val_loss improved from -0.19173 to -0.20497, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9854 - dice_coefficient: 1.0903 - loss: -0.2072 - val_accuracy: 0.9851 - val_dice_coefficient: 1.0826 - val_loss: -0.2050 - learning_rate: 2.0000e-04
# Epoch 16/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9859 - dice_coefficient: 1.0765 - loss: -0.1871
# Epoch 16: val_loss did not improve from -0.20497
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9859 - dice_coefficient: 1.0766 - loss: -0.1872 - val_accuracy: 0.9853 - val_dice_coefficient: 1.0820 - val_loss: -0.2037 - learning_rate: 2.0000e-04
# Epoch 17/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9849 - dice_coefficient: 1.0914 - loss: -0.2178
# Epoch 17: val_loss improved from -0.20497 to -0.21389, saving model to model10.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 303s 3s/step - accuracy: 0.9849 - dice_coefficient: 1.0913 - loss: -0.2177 - val_accuracy: 0.9853 - val_dice_coefficient: 1.0886 - val_loss: -0.2139 - learning_rate: 2.0000e-04
# Epoch 18/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9851 - dice_coefficient: 1.1035 - loss: -0.2335
# Epoch 18: val_loss did not improve from -0.21389
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 577s 5s/step - accuracy: 0.9851 - dice_coefficient: 1.1034 - loss: -0.2333 - val_accuracy: 0.9853 - val_dice_coefficient: 1.0589 - val_loss: -0.1686 - learning_rate: 2.0000e-04
# Epoch 19/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9856 - dice_coefficient: 1.1021 - loss: -0.2253
# Epoch 19: val_loss did not improve from -0.21389
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 575s 5s/step - accuracy: 0.9856 - dice_coefficient: 1.1020 - loss: -0.2252 - val_accuracy: 0.9855 - val_dice_coefficient: 1.0871 - val_loss: -0.2101 - learning_rate: 2.0000e-04
# Epoch 20/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9854 - dice_coefficient: 1.1054 - loss: -0.2293
# Epoch 20: val_loss did not improve from -0.21389
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 575s 5s/step - accuracy: 0.9854 - dice_coefficient: 1.1054 - loss: -0.2293 - val_accuracy: 0.9838 - val_dice_coefficient: 1.0743 - val_loss: -0.1932 - learning_rate: 2.0000e-04
# Training completed successfully.
# Model saved successfully.

# %%
import matplotlib.pyplot as plt
def show_history(history, train, validation):
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.title('Train History')
    plt.ylabel('train')
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='center right')
    plt.show()
show_history(history, 'dice_coefficient', 'val_dice_coefficient')

# %%
show_history(history, 'loss', 'val_loss')

# %%
scores = model.evaluate(x_valid, y_valid)
scores[1]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9829 - dice_coefficient: 1.0940 - loss: -0.2283
# 0.9837638139724731

# %%
prediction = model.predict(x_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step

# %%
test_scores = model.evaluate(x_test, y_test)
test_scores[1]
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9845 - dice_coefficient: 1.0933 - loss: -0.2148
# 0.985243558883667

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have x_test and y_test
# Replace this with the actual index of the image you want to visualize
image_index = 9

# Load the image and true mask
input_image = x_test[image_index]
true_mask = y_test[image_index]

predicted_mask = model.predict(np.expand_dims(input_image, axis=0))[0]

threshold = 0.1 
predicted_mask_binary = (predicted_mask > threshold).astype(np.uint8)

plt.figure(figsize=(12, 4))

plt.figure(figsize=(12, 3))

plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(true_mask[:, :, 0], cmap='gray')
plt.title('True Mask')

plt.subplot(1,3, 3)
plt.imshow(predicted_mask_binary, cmap='gray')
plt.title('Predicted Mask')


plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
